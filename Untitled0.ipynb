# %% [markdown]
# <a href="https://colab.research.google.com/github/Quemas01-Mc/Programas-simples-de-pyhton/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Ejercicio de hola mundo

# %% [markdown]
# ##Hola mundo con python
#
# Python es un lenguje

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ##Hola mundo con bash

# %%
# !echo "Hola Mundo desde la Terminal"
# Out:
# Hola Mundo desde la Terminal

# %% [markdown]
# ##Hola mundo con c++

# %%
# %%writefile hola.cpp
# #include <iostream>
# int main() {
#     std::cout << "Hola Mundo desde C++" << std::endl;
#     return 0;
# }
# Out:
# Overwriting hola.cpp

# %% [markdown]
# ###Hola mundo con JavaScript

# %%
# %%javascript
# alert("¡Hola Mundo desde JavaScript!");
# console.log("Mira la consola del navegador");
